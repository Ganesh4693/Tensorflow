# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('max_columns',30)
sns.set_theme(font_scale=1.5)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %% [markdown]
# ## Reading data

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# ### Check for nulls

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### No missing data

# %% [markdown]
# ## EDA

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(15,10))
sns.distplot(df['price'])
plt.ticklabel_format(style='plain', axis='both')
# Out:
# c:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['bedrooms'])
# Out:
# c:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %% [markdown]
# ### Correlations

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %% [markdown]
# ### Highest correlations

# %%
df.corr()['price'].sort_values(ascending=False)[1:6]
# Out:
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='price',y='sqft_living',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
plt.figure(figsize=(15,10))
sns.boxplot(y='price',x='bedrooms',data=df)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ### Lattitude and longitude

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='price',y='long',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='price',y='lat',data=df)
plt.ticklabel_format(style='plain', axis='both')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %% [markdown]
# ### Removing outliers

# %%
df.sort_values(by='price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %% [markdown]
# ### We can remove top 1% based on price

# %%
len(df)*0.01
# Out:
# 215.97

# %%
    df1=df.sort_values(by='price',ascending=False).iloc[216:]

# %% [markdown]
# ### EDA on bottom 99%

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='long',y='lat',data=df1,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='long',y='lat',data=df1,hue='price',edgecolor=None,alpha=0.1,palette='RdYlGn_r')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %% [markdown]
# ### More expensive near waterfront

# %%
plt.figure(figsize=(15,10))
sns.boxplot(y='price',x='waterfront',data=df)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.drop('id',axis=1,inplace=True)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year']=df['date'].apply(lambda date: date.year)
df['month']=df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
plt.figure(figsize=(15,10))
sns.boxplot(y='price',x='month',data=df)
plt.ticklabel_format(style='plain', axis='y')

# %%
plt.figure(figsize=(15,10))
sns.boxplot(y='price',x='year',data=df)
plt.ticklabel_format(style='plain', axis='y')

# %%
df.groupby('month').mean()['price'].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %% [markdown]
# ### To see if zipcode is a viable categorical column

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# ### zipcode is not a viable column as there are 70 categories

# %%
df.drop('zipcode',axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df.yr_renovated.value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# #### zero values correspond to no renovation.
# ### Since recent renovations lead to more House value No need to change zero values

# %% [markdown]
# ### Similarly for sqft_basement

# %%
df.sqft_basement.value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# ## Data splitting and scaling

# %%
X=df.drop('price',axis=1).values
y=df.price.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %% [markdown]
# ## Deep Learning Model

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model=Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=700)
# Out:
# Epoch 1/700
# 119/119 [==============================] - 2s 8ms/step - loss: 430240792576.0000 - val_loss: 418913648640.0000
# Epoch 2/700
# 119/119 [==============================] - 1s 5ms/step - loss: 428996296704.0000 - val_loss: 414510579712.0000
# Epoch 3/700
# 119/119 [==============================] - 1s 6ms/step - loss: 410758381568.0000 - val_loss: 372641628160.0000
# Epoch 4/700
# 119/119 [==============================] - 1s 5ms/step - loss: 322612428800.0000 - val_loss: 234566418432.0000
# Epoch 5/700
# 119/119 [==============================] - 1s 5ms/step - loss: 166148702208.0000 - val_loss: 106415841280.0000
# Epoch 6/700
# 119/119 [==============================] - 1s 5ms/step - loss: 100856913920.0000 - val_loss: 94357921792.0000
# Epoch 7/700
# 119/119 [==============================] - 1s 6ms/step - loss: 96786587648.0000 - val_loss: 92800630784.0000
# Epoch 8/700
# ...

# %% [markdown]
# ## Predictions and Evaluation

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot(figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
predictions=model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 3ms/step

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 139980.52349962373

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 81883.88161651234

# %%
df.price.describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# ### Mean Price

# %%
5.402966e+05
# Out:
# 540296.6

# %% [markdown]
# ### Error percent

# %%
mean_absolute_error(y_test,predictions)/5.402966e+05*100
# Out:
# 15.155357560368202

# %% [markdown]
# ### About 15 % error

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8522734297258808

# %% [markdown]
# ### We can keep training the deep learning model

# %%
plt.figure(figsize=(15,10))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')
plt.ticklabel_format(style='plain',axis='both')

# %% [markdown]
# ### Testing model on a single house data

# %%
single_house=df.drop('price',axis=1).iloc[0]

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array([[278398.7]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
percent_error=(278398.7-221900)/221900

# %%
percent_error*100
# Out:
# 25.4613339342046
